# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scripts.functions import load_process

# %%
df = load_process("../../data/raw/Chess-Game-Dataset.csv")

# %%
df
# Out:
#          created_at  last_move_at  turns victory_status winner increment_code  \
# 1      1.504130e+12  1.504130e+12     16         resign  black           5+10
# 2      1.504130e+12  1.504130e+12     61           mate  white           5+10
# 3      1.504110e+12  1.504110e+12     61           mate  white           20+0
# 4      1.504030e+12  1.504030e+12     95           mate  white           30+3
# 5      1.504240e+12  1.504240e+12      5           draw   draw           10+0
# ...             ...           ...    ...            ...    ...            ...
# 20053  1.499791e+12  1.499791e+12     24         resign  white          10+10
# 20054  1.499698e+12  1.499699e+12     82           mate  black           10+0
# 20055  1.499698e+12  1.499698e+12     35           mate  white           10+0
# 20056  1.499696e+12  1.499697e+12    109         resign  white           10+0
# 20057  1.499643e+12  1.499644e+12     78           mate  black           10+0
#
# ...

# %%
df.columns
# Out:
# Index(['created_at', 'last_move_at', 'turns', 'victory_status', 'winner',
#        'increment_code', 'white_rating', 'black_rating', 'moves',
#        'opening_eco', 'opening_name'],
#       dtype='object')

# %%
df.groupby('winner')

# %%
df.describe(exclude=np.object).T
# Out:
#                 count          mean           std           min           25%  \
# created_at    18378.0  1.483830e+12  2.829286e+10  1.376772e+12  1.477788e+12
# last_move_at  18378.0  1.483830e+12  2.829277e+10  1.376772e+12  1.477788e+12
# turns         18378.0  5.934373e+01  3.279124e+01  1.000000e+00  3.600000e+01
# white_rating  18378.0  1.595169e+03  2.902818e+02  7.840000e+02  1.397000e+03
# black_rating  18378.0  1.586920e+03  2.906106e+02  7.890000e+02  1.389000e+03
#
#                        50%           75%           max
# created_at    1.496179e+12  1.503170e+12  1.504493e+12
# last_move_at  1.496180e+12  1.503170e+12  1.504494e+12
# turns         5.400000e+01  7.700000e+01  2.590000e+02
# white_rating  1.565000e+03  1.791000e+03  2.700000e+03
# black_rating  1.558000e+03  1.781000e+03  2.621000e+03

# %%
df.describe(exclude=np.number).T
# Out:
#                 count unique                   top   freq
# victory_status  18378      3                resign  11147
# winner          18378      3                 white   9188
# increment_code  18378    395                  10+0   6958
# moves           18378  17363                 e4 e5     20
# opening_eco     18378    360                   A00    928
# opening_name    18378   1440  Van't Kruijs Opening    341

# %%
df_opening = df[df['opening_name']=="Van't Kruijs Opening"]
df_opening
df_opening.describe(include=np.object).T
# Out:
#                count unique                   top freq
# victory_status   341      3                resign  171
# winner           341      3                 black  205
# increment_code   341     79                  10+0   89
# moves            341    301                 e3 e5    8
# opening_eco      341      1                   A00  341
# opening_name     341      1  Van't Kruijs Opening  341

# %%
df.isna().sum()
# Out:
# created_at        0
# last_move_at      0
# turns             0
# victory_status    0
# winner            0
# increment_code    0
# white_rating      0
# black_rating      0
# moves             0
# opening_eco       0
# opening_name      0
# dtype: int64
